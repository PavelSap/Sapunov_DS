# %% [markdown]
# # Модель кредитного скоринга: предобработка данных.
#
# **Описание задачи**:
#
# Банку требуется создать модель кредитного скоринга, для этого нужно провести преобработку данных о клиентах.
#
# Помимо обработки данных выделю новые признаки для построения модели, а также проведу первичный анализ для составления портрета заемщика, склонного к задолженности.

# %% [markdown]
# ## Обзор данных

# %% [markdown]
# Проведу обзор данных, посмотрим, какие типы данных в датафрейме:

# %%
import pandas as pd
data = pd.read_csv('/datasets/data.csv')
display(data)
data.info()
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1   -8437.673028         42    высшее             0
# 1             1   -4024.803754         36   среднее             1
# 2             0   -5623.422610         33   Среднее             1
# 3             3   -4124.747207         32   среднее             1
# 4             0  340266.072047         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1   -4529.316663         43   среднее             1
# 21521         0  343937.404131         67   среднее             1
# 21522         1   -2113.346888         38   среднее             1
# 21523         3   -3112.481705         38   среднее             1
# 21524         2   -1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 0      253875.639453                 покупка жилья
# 1      112080.014102       приобретение автомобиля
# 2      145885.952297                 покупка жилья
# 3      267628.550329    дополнительное образование
# 4      158616.077870               сыграть свадьбу
# ...              ...                           ...
# 21520  224791.862382             операции с жильем
# 21521  155999.806512          сделка с автомобилем
# 21522   89672.561153                  недвижимость
# 21523  244093.050500  на покупку своего автомобиля
# 21524   82047.418899         на покупку автомобиля
#
# [21525 rows x 12 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Обзор данных показывает наличие пропусков в столбцах days_employed и total_income, возможно это связано с тем, что некоторые клиенты просто не указывали эти данные. Но при этом количество пропусков одинаковое, возможно у части клиентов не запрашивали данные по этим категориям. Далее я заполню данные медианным значение, что допустимо для количественных данных. Для большей точности предпочтительно ориентироваться на данные не только конкрентного столбца, но и смежных столбцов, например, таким образом я заполнял пропуски в столбце total_income в зависимости от разных типо дохода, содержащихся в стоблце income_type.

# %% [markdown]
# ## Заполнение пропусков и проверка данных на аномалии

# %% [markdown]
# Посчитаю пропуски в данных и их долю.

# %%
print(data.isna().sum())
print(f'Доля пропущенных значений: {2174/21525:.2%}') # это доля пропущенных значений, которые были
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64
# Доля пропущенных значений: 10.10%

# %% [markdown]
# Я проверил, что в датафрейме есть отрицательные значения, хотя их быть не должно по логике данных.

# %%
display(data[data['days_employed'] < 0])
# Out:
#        children  days_employed  dob_years       education  education_id  \
# 0             1   -8437.673028         42          высшее             0
# 1             1   -4024.803754         36         среднее             1
# 2             0   -5623.422610         33         Среднее             1
# 3             3   -4124.747207         32         среднее             1
# 5             0    -926.185831         27          высшее             0
# ...         ...            ...        ...             ...           ...
# 21519         1   -2351.431934         37  ученая степень             4
# 21520         1   -4529.316663         43         среднее             1
# 21522         1   -2113.346888         38         среднее             1
# 21523         3   -3112.481705         38         среднее             1
# 21524         2   -1984.507589         40         среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 5      гражданский брак                 1      M   компаньон     0
# ...                 ...               ...    ...         ...   ...
# 21519         в разводе                 3      M   сотрудник     0
# 21520  гражданский брак                 1      F   компаньон     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                            purpose
# 0      253875.639453                      покупка жилья
# 1      112080.014102            приобретение автомобиля
# 2      145885.952297                      покупка жилья
# 3      267628.550329         дополнительное образование
# 5      255763.565419                      покупка жилья
# ...              ...                                ...
# 21519  115949.039788  покупка коммерческой недвижимости
# 21520  224791.862382                  операции с жильем
# 21522   89672.561153                       недвижимость
# 21523  244093.050500       на покупку своего автомобиля
# 21524   82047.418899              на покупку автомобиля
#
# [15906 rows x 12 columns]

# %% [markdown]
# Заменим медианным значением, но сначала удалим отрицательные значения.

# %%
data['days_employed'] = abs(data['days_employed'])
display(data) #убираем отрицательные значения, те. приводим к модулю
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   Среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0  340266.072047         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1    4529.316663         43   среднее             1
# 21521         0  343937.404131         67   среднее             1
# 21522         1    2113.346888         38   среднее             1
# 21523         3    3112.481705         38   среднее             1
# 21524         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 0      253875.639453                 покупка жилья
# 1      112080.014102       приобретение автомобиля
# 2      145885.952297                 покупка жилья
# 3      267628.550329    дополнительное образование
# 4      158616.077870               сыграть свадьбу
# ...              ...                           ...
# 21520  224791.862382             операции с жильем
# 21521  155999.806512          сделка с автомобилем
# 21522   89672.561153                  недвижимость
# 21523  244093.050500  на покупку своего автомобиля
# 21524   82047.418899         на покупку автомобиля
#
# [21525 rows x 12 columns]

# %% [markdown]
# Заменим медианным значением для каждого типа дохода:

# %%
income_types = data['income_type'].unique()
for type in income_types:
    data['days_employed'] = data['days_employed'].fillna(data[data['income_type'] == type]['days_employed'].median())
    data['total_income'] = data['total_income'].fillna(data[data['income_type'] == type]['total_income'].median())

# %%
data.info() #проверяем
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     21525 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      21525 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Еще в столбце 'children' есть отрицательное значение, изменим его на положительное.
# А также примем, что 20 детей у заемщика это опечатка, и заменим эти значения на '2'.

# %%
data['children'].unique()
data['children'] = abs(data['children'])
try:
    data.loc[data['children'] == 20, 'children'] = 2
except:
    print('20 не поменялось на 2')

# %% [markdown]
# В столбце 'days_employed' очень большие значения, из условия я знаю, что это количество дней.

# %%
data['days_employed'].sort_values()
# Out:
# 17437        24.141633
# 8336         24.240695
# 6157         30.195337
# 9683         33.520665
# 2127         34.701045
#              ...
# 7794     401663.850046
# 2156     401674.466633
# 7664     401675.093434
# 10006    401715.811749
# 6954     401755.400475
# Name: days_employed, Length: 21525, dtype: float64

# %% [markdown]
# Применим несколько методов к столбцу days_employed для выявления возможных аномалий.

# %%
data_check = data.groupby('income_type').agg({'days_employed': ['median', 'mean', 'max', 'min', 'count']})
display(data_check) # Получается, что самые аномальные цифры у пенсионеров и безработных
# Out:
#                  days_employed                                               \
#                         median           mean            max            min
# income_type
# безработный      366413.652744  366413.652744  395302.838654  337524.466835
# в декрете          3296.759962    3296.759962    3296.759962    3296.759962
# госслужащий        2385.358043    3215.951028   15193.032201      39.954170
# компаньон          1574.202821    2057.845075   17615.563266      30.195337
# пенсионер        360505.668544  326078.103247  401755.400475    1574.202821
# предприниматель    1047.525452    1047.525452    1574.202821     520.848083
# сотрудник          1574.202821    2251.736421   18388.949901      24.141633
# студент             578.751554     578.751554     578.751554     578.751554
#
#
#                  count
# income_type
# безработный          2
# в декрете            1
# госслужащий       1459
# компаньон         5085
# пенсионер         3856
# предприниматель      2
# сотрудник        11119
# студент              1

# %% [markdown]
# Дополнительной информации у нас нет, но 1000 лет стажа нет даже в самых крутых резюме.
# Я могу предположить, что здесь указаны часы.
# Переведу у пенсионеров и безработных часы в дни, а потом создам колонку со стажем в годах для удобства.

# %%
data.loc[data['income_type'] == 'пенсионер', 'days_employed'] /= 24
data.loc[data['income_type'] == 'безработный', 'days_employed'] /= 24
data['years_employed'] = data['days_employed'] / 365
display(data)
#в столбце с годами стажа нет явных аномальных значений
display(data['years_employed'].sort_values())
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   Среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0   14177.753002         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1    4529.316663         43   среднее             1
# 21521         0   14330.725172         67   среднее             1
# 21522         1    2113.346888         38   среднее             1
# 21523         3    3112.481705         38   среднее             1
# 21524         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose  years_employed
# 0      253875.639453                 покупка жилья       23.116912
# 1      112080.014102       приобретение автомобиля       11.026860
# 2      145885.952297                 покупка жилья       15.406637
# 3      267628.550329    дополнительное образование       11.300677
# 4      158616.077870               сыграть свадьбу       38.843159
# ...              ...                           ...             ...
# 21520  224791.862382             операции с жильем       12.409087
# 21521  155999.806512          сделка с автомобилем       39.262261
# 21522   89672.561153                  недвижимость        5.789991
# 21523  244093.050500  на покупку своего автомобиля        8.527347
# 21524   82047.418899         на покупку автомобиля        5.437007
#
# [21525 rows x 13 columns]
# 17437     0.066141
# 8336      0.066413
# 6157      0.082727
# 9683      0.091837
# 2127      0.095071
#            ...
# 7664     45.853321
# 10006    45.857969
# 6954     45.862489
# 4299     48.261817
# 16335    50.380685
# Name: years_employed, Length: 21525, dtype: float64

# %% [markdown]
# В столбце dob_years содержится возраст 0, это ошибка.
# Также посчитаю, в скольких строках указан возраст 0.

# %%
print(data['dob_years'].unique())
print(data[data['dob_years'] == 0].count())
# Out:
# [42 36 33 32 53 27 43 50 35 41 40 65 54 56 26 48 24 21 57 67 28 63 62 47
#  34 68 25 31 30 20 49 37 45 61 64 44 52 46 23 38 39 51  0 59 29 60 55 58
#  71 22 73 66 69 19 72 70 74 75]
# children            101
# days_employed       101
# dob_years           101
# education           101
# education_id        101
# family_status       101
# family_status_id    101
# gender              101
# income_type         101
# debt                101
# total_income        101
# purpose             101
# years_employed      101
# dtype: int64

# %% [markdown]
# Заменю на медианное значение по каждой группе:

# %%
for type in income_types:
    data.loc[(data['dob_years'] == 0) & (data['income_type'] == type), 'dob_years'] = data[data['income_type'] == type]['dob_years'].median()
print(data['dob_years'].unique())
# Out:
# [42. 36. 33. 32. 53. 27. 43. 50. 35. 41. 40. 65. 54. 56. 26. 48. 24. 21.
#  57. 67. 28. 63. 62. 47. 34. 68. 25. 31. 30. 20. 49. 37. 45. 61. 64. 44.
#  52. 46. 23. 38. 39. 51. 60. 59. 29. 55. 58. 71. 22. 73. 66. 69. 19. 72.
#  70. 74. 75.]

# %% [markdown]
# ## Изменение типов данных

# %% [markdown]
# Для удобства подсчета и визуализации изменю тип данных с вещественного на целочисленный в столбцах total_income, dob_years и years_employed.

# %%
data['total_income'] = data['total_income'].astype('int')
data['dob_years'] = data['dob_years'].astype('int')
data['years_employed'] = data['years_employed'].astype('int')
display(data)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   Среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0   14177.753002         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1    4529.316663         43   среднее             1
# 21521         0   14330.725172         67   среднее             1
# 21522         1    2113.346888         38   среднее             1
# 21523         3    3112.481705         38   среднее             1
# 21524         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose  years_employed
# 0            253875                 покупка жилья              23
# 1            112080       приобретение автомобиля              11
# 2            145885                 покупка жилья              15
# 3            267628    дополнительное образование              11
# 4            158616               сыграть свадьбу              38
# ...             ...                           ...             ...
# 21520        224791             операции с жильем              12
# 21521        155999          сделка с автомобилем              39
# 21522         89672                  недвижимость               5
# 21523        244093  на покупку своего автомобиля               8
# 21524         82047         на покупку автомобиля               5
#
# [21525 rows x 13 columns]

# %% [markdown]
# ## Удаление дубликатов

# %% [markdown]
# Проверю датафрейм на наличие дубликатов и выведу строки с дубликатами.

# %%
print(data.duplicated().sum())
display(data[data.duplicated()])
# Out:
# 54
#        children  days_employed  dob_years education  education_id  \
# 2849          0    1574.202821         41   среднее             1
# 4182          1    1574.202821         34    ВЫСШЕЕ             0
# 4851          0      65.591784         60   среднее             1
# 5557          0      65.591784         58   среднее             1
# 7808          0      65.591784         57   среднее             1
# 8583          0      65.591784         58    высшее             0
# 9238          2    1574.202821         34   среднее             1
# 9528          0      65.591784         66   среднее             1
# 9627          0      65.591784         56   среднее             1
# 10462         0      65.591784         62   среднее             1
# 10697         0    1574.202821         40   среднее             1
# 10864         0      65.591784         62   среднее             1
# 10994         0      65.591784         62   среднее             1
# 11791         0    1574.202821         47   среднее             1
# 12373         0    1574.202821         58   среднее             1
# 12375         1    1574.202821         37   среднее             1
# 12736         0      65.591784         59   среднее             1
# 13025         1    1574.202821         44   среднее             1
# 13639         0      65.591784         64   среднее             1
# 13773         0    1574.202821         35   среднее             1
# 13878         1    1574.202821         31   среднее             1
# 13942         0    1574.202821         44   среднее             1
# 14432         2    1574.202821         36    высшее             0
# 14832         0    1574.202821         50   среднее             1
# 15091         0    1574.202821         58   среднее             1
# 15188         0    1574.202821         60   среднее             1
# 15273         0      65.591784         57   среднее             1
# 16176         0    1574.202821         47   среднее             1
# 16378         0    1574.202821         46   среднее             1
# 16902         2    1574.202821         39   среднее             1
# 16904         1    1574.202821         32    высшее             0
# 17379         0    1574.202821         54    высшее             0
# 17755         1    1574.202821         43   среднее             1
# 17774         1    1574.202821         40   среднее             1
# 18328         0    1574.202821         29    высшее             0
# 18349         1    1574.202821         30    высшее             0
# 18428         0      65.591784         64   среднее             1
# 18521         0    1574.202821         56   среднее             1
# 18563         0    1574.202821         54   среднее             1
# 18755         0      65.591784         58   среднее             1
# 19041         0    1574.202821         56   среднее             1
# 19184         0    1574.202821         46   среднее             1
# 19321         0    1574.202821         23   среднее             1
# 19387         0    1574.202821         38    высшее             0
# 19688         0      65.591784         61   среднее             1
# 19832         0    1574.202821         48   среднее             1
# 19946         0    1574.202821         57   среднее             1
# 20116         0      65.591784         57   среднее             1
# 20165         0    1574.202821         42   среднее             1
# 20702         0      65.591784         64   среднее             1
# 21032         0      65.591784         60   среднее             1
# 21132         0    1574.202821         47   среднее             1
# 21281         1    1574.202821         30    высшее             0
# 21415         0      65.591784         54   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 2849         женат / замужем                 0      F    сотрудник     0
# 4182        гражданский брак                 1      F    сотрудник     0
# 4851        гражданский брак                 1      F    пенсионер     0
# 5557        гражданский брак                 1      F    пенсионер     0
# 7808        гражданский брак                 1      F    пенсионер     0
# 8583   Не женат / не замужем                 4      F    пенсионер     0
# 9238         женат / замужем                 0      F    сотрудник     0
# 9528          вдовец / вдова                 2      F    пенсионер     0
# 9627         женат / замужем                 0      F    пенсионер     0
# 10462        женат / замужем                 0      F    пенсионер     0
# 10697       гражданский брак                 1      F    компаньон     0
# 10864        женат / замужем                 0      F    пенсионер     0
# 10994        женат / замужем                 0      F    пенсионер     0
# 11791        женат / замужем                 0      F    сотрудник     0
# 12373        женат / замужем                 0      M    сотрудник     0
# 12375        женат / замужем                 0      F    сотрудник     0
# 12736        женат / замужем                 0      F    пенсионер     0
# 13025        женат / замужем                 0      F    сотрудник     0
# 13639        женат / замужем                 0      F    пенсионер     0
# 13773       гражданский брак                 1      F    сотрудник     0
# 13878        женат / замужем                 0      F    компаньон     0
# 13942        женат / замужем                 0      F    сотрудник     0
# 14432        женат / замужем                 0      F  госслужащий     0
# 14832  Не женат / не замужем                 4      F    сотрудник     0
# 15091       гражданский брак                 1      M    сотрудник     0
# 15188        женат / замужем                 0      M    сотрудник     0
# 15273       гражданский брак                 1      F    пенсионер     0
# 16176        женат / замужем                 0      F    сотрудник     0
# 16378        женат / замужем                 0      F    сотрудник     0
# 16902       гражданский брак                 1      F    сотрудник     0
# 16904        женат / замужем                 0      F    сотрудник     0
# 17379        женат / замужем                 0      M    компаньон     0
# 17755        женат / замужем                 0      M    сотрудник     0
# 17774       гражданский брак                 1      F    компаньон     0
# 18328        женат / замужем                 0      M    сотрудник     0
# 18349        женат / замужем                 0      F  госслужащий     0
# 18428        женат / замужем                 0      F    пенсионер     0
# 18521       гражданский брак                 1      F    сотрудник     0
# 18563        женат / замужем                 0      F    сотрудник     0
# 18755        женат / замужем                 0      F    пенсионер     0
# 19041       гражданский брак                 1      F    сотрудник     0
# 19184        женат / замужем                 0      F    сотрудник     0
# 19321  Не женат / не замужем                 4      F    сотрудник     0
# 19387       гражданский брак                 1      F    компаньон     0
# 19688        женат / замужем                 0      F    пенсионер     0
# 19832        женат / замужем                 0      F    сотрудник     0
# 19946        женат / замужем                 0      F    сотрудник     0
# 20116       гражданский брак                 1      M    пенсионер     0
# 20165        женат / замужем                 0      F    сотрудник     0
# 20702        женат / замужем                 0      F    пенсионер     0
# 21032        женат / замужем                 0      F    пенсионер     0
# 21132        женат / замужем                 0      F    сотрудник     0
# 21281        женат / замужем                 0      F    сотрудник     0
# 21415        женат / замужем                 0      F    пенсионер     0
#
#        total_income                                purpose  years_employed
# 2849         142594                покупка жилья для семьи               4
# 4182         142594                                свадьба               4
# 4851         142594                                свадьба               0
# 5557         142594                        сыграть свадьбу               0
# 7808         142594                  на проведение свадьбы               0
# 8583         142594             дополнительное образование               0
# 9238         142594                покупка жилья для сдачи               4
# 9528         142594        операции со своей недвижимостью               0
# 9627         142594        операции со своей недвижимостью               0
# 10462        142594      покупка коммерческой недвижимости               0
# 10697        142594                        сыграть свадьбу               4
# 10864        142594                           ремонт жилью               0
# 10994        142594                           ремонт жилью               0
# 11791        142594             строительство недвижимости               4
# 12373        142594                   покупка недвижимости               4
# 12375        142594                   покупка недвижимости               4
# 12736        142594                  заняться образованием               0
# 13025        142594       сделка с подержанным автомобилем               4
# 13639        142594                             автомобиль               0
# 13773        142594                        сыграть свадьбу               4
# 13878        142594                          покупка жилья               4
# 13942        142594                приобретение автомобиля               4
# 14432        142594                  получение образования               4
# 14832        142594                           недвижимость               4
# 15091        142594                  на проведение свадьбы               4
# 15188        142594                   покупка недвижимости               4
# 15273        142594                                свадьба               0
# 16176        142594                           ремонт жилью               4
# 16378        142594                     высшее образование               4
# 16902        142594                        сыграть свадьбу               4
# 16904        142594     на покупку подержанного автомобиля               4
# 17379        142594  операции с коммерческой недвижимостью               4
# 17755        142594                  заняться образованием               4
# 17774        142594       строительство жилой недвижимости               4
# 18328        142594             покупка жилой недвижимости               4
# 18349        142594                покупка жилья для семьи               4
# 18428        142594                                  жилье               0
# 18521        142594                        сыграть свадьбу               4
# 18563        142594        операции со своей недвижимостью               4
# 18755        142594                  заняться образованием               0
# 19041        142594                  на проведение свадьбы               4
# 19184        142594                        свой автомобиль               4
# 19321        142594       сделка с подержанным автомобилем               4
# 19387        142594                  на проведение свадьбы               4
# 19688        142594               операции с недвижимостью               0
# 19832        142594                           ремонт жилью               4
# 19946        142594       сделка с подержанным автомобилем               4
# 20116        142594                                свадьба               0
# 20165        142594                покупка жилья для семьи               4
# 20702        142594             дополнительное образование               0
# 21032        142594                  заняться образованием               0
# 21132        142594                           ремонт жилью               4
# 21281        142594      покупка коммерческой недвижимости               4
# 21415        142594                      операции с жильем               0

# %% [markdown]
# Здесь требуется избавится от неявных дубликатов, сначала посмотрю спиксок уникальных значений.
# Затем перезапишу столбец, переведя значения в нижний регистр.

# %%
print(data['education'].value_counts())
data['education'] = data['education'].str.lower()
# Out:
# среднее                13750
# высшее                  4718
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   274
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# Ученая степень             1
# УЧЕНАЯ СТЕПЕНЬ             1
# Name: education, dtype: int64

# %% [markdown]
# Удалю явные дубликаты с присвоением новой индексации.

# %%
data = data.drop_duplicates().reset_index(drop=True)
display(data)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0   14177.753002         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21449         1    4529.316663         43   среднее             1
# 21450         0   14330.725172         67   среднее             1
# 21451         1    2113.346888         38   среднее             1
# 21452         3    3112.481705         38   среднее             1
# 21453         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21449  гражданский брак                 1      F   компаньон     0
# 21450   женат / замужем                 0      F   пенсионер     0
# 21451  гражданский брак                 1      M   сотрудник     1
# 21452   женат / замужем                 0      M   сотрудник     1
# 21453   женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose  years_employed
# 0            253875                 покупка жилья              23
# 1            112080       приобретение автомобиля              11
# 2            145885                 покупка жилья              15
# 3            267628    дополнительное образование              11
# 4            158616               сыграть свадьбу              38
# ...             ...                           ...             ...
# 21449        224791             операции с жильем              12
# 21450        155999          сделка с автомобилем              39
# 21451         89672                  недвижимость               5
# 21452        244093  на покупку своего автомобиля               8
# 21453         82047         на покупку автомобиля               5
#
# [21454 rows x 13 columns]

# %% [markdown]
# Проверю неявные дубликаты в колонке family_status.

# %%
print(data['family_status'].value_counts())
# Out:
# женат / замужем          12339
# гражданский брак          4151
# Не женат / не замужем     2810
# в разводе                 1195
# вдовец / вдова             959
# Name: family_status, dtype: int64

# %% [markdown]
# Дубликатов нет, но исправим прописные буквы на строчные

# %%
data['family_status'] = data['family_status'].str.lower()

# %% [markdown]
# Проверю неявные дубликаты в столбце 'purpose'.

# %%
print(data['purpose'].value_counts())
# Out:
# свадьба                                   791
# на проведение свадьбы                     768
# сыграть свадьбу                           765
# операции с недвижимостью                  675
# покупка коммерческой недвижимости         661
# операции с жильем                         652
# покупка жилья для сдачи                   651
# операции с коммерческой недвижимостью     650
# жилье                                     646
# покупка жилья                             646
# покупка жилья для семьи                   638
# строительство собственной недвижимости    635
# недвижимость                              633
# операции со своей недвижимостью           627
# строительство жилой недвижимости          624
# покупка недвижимости                      621
# покупка своего жилья                      620
# строительство недвижимости                619
# ремонт жилью                              607
# покупка жилой недвижимости                606
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                494
# сделка с подержанным автомобилем          486
# на покупку подержанного автомобиля        478
# автомобили                                478
# свой автомобиль                           478
# на покупку автомобиля                     471
# приобретение автомобиля                   461
# дополнительное образование                460
# сделка с автомобилем                      455
# высшее образование                        452
# образование                               447
# получение дополнительного образования     446
# получение образования                     442
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     408
# Name: purpose, dtype: int64

# %% [markdown]
# Здесь содержатся неявные дубликаты, удалю их с использованием метода .replace() и создания функции.
# В дальнейшем можно выделить только 4 категории: свадьба, недвижимость, автомобиль, образование.
# Но я думаю, что более детальная информация теоретически может понадобиться при дальнейшем анализе (например, коммерческая или жилая недвижимость и тд.), поэтому я устранил самые явные дубликаты.
# Заодно исправлю опечатку в названии категории 'ремонт жилью'.

# %%
def replace_duplicates(duplicates, correct):
    for duplicate in duplicates:
        data['purpose'] = data['purpose'].replace(duplicate,correct)
        
wedding_duplicates = ['на проведение свадьбы','сыграть свадьбу']
wedding_correct = 'свадьба'
replace_duplicates(wedding_duplicates, wedding_correct)

commercial_property_duplicates = ['операции с коммерческой недвижимостью']
commercial_property_correct = 'покупка коммерческой недвижимости'
replace_duplicates(commercial_property_duplicates, commercial_property_correct)

real_estate_duplicates = ['покупка жилья', 'покупка жилья для семьи', 'покупка своего жилья', 'покупка жилой недвижимости', 'операции с жильем']
real_estate_correct = 'жилье'
replace_duplicates(real_estate_duplicates, real_estate_correct)

property_operation_duplicates = ['операции со своей недвижимостью', 'операции с недвижимостью', 'покупка недвижимости']
property_operation_correct = 'недвижимость'                               
replace_duplicates(property_operation_duplicates, property_operation_correct)

construction_duplicates = 'строительство собственной недвижимости'
construction_correct = 'строительство недвижимости'
replace_duplicates(construction_duplicates, construction_correct)

auto_duplicates = ['на покупку своего автомобиля', 'свой автомобиль', 'автомобили', 'на покупку автомобиля', 'приобретение автомобиля', 'сделка с автомобилем']
auto_correct = 'автомобиль'
replace_duplicates(auto_duplicates, auto_correct)

used_auto_duplicates = ['на покупку подержанного автомобиля']
used_auto_correct = 'сделка с подержанным автомобилем'
replace_duplicates(used_auto_duplicates, used_auto_correct)

education_duplicates = ['получение образования', 'заняться образованием']
education_correct = 'образование'
replace_duplicates(education_duplicates, education_correct)

higher_education_duplicates = ['получение высшего образования', 'заняться высшим образованием']
higher_education_correct = 'высшее образование'
replace_duplicates(higher_education_duplicates, higher_education_correct)

add_education_duplicates = ['получение дополнительного образования']
add_education_correct = 'дополнительное образование'
replace_duplicates(add_education_duplicates, add_education_correct)

data.loc[data['purpose'] == 'ремонт жилью', 'purpose'] = 'ремонт жилья'

# %%
print(data['purpose'].value_counts()) # проверим результат
# Out:
# жилье                                     3808
# автомобиль                                3342
# недвижимость                              2556
# свадьба                                   2324
# высшее образование                        1374
# покупка коммерческой недвижимости         1311
# образование                               1297
# сделка с подержанным автомобилем           964
# дополнительное образование                 906
# покупка жилья для сдачи                    651
# строительство собственной недвижимости     635
# строительство жилой недвижимости           624
# строительство недвижимости                 619
# ремонт жилья                               607
# профильное образование                     436
# Name: purpose, dtype: int64

# %% [markdown]
# ## Формирование дополнительных датафреймов словарей, декомпозиция исходного датафрейма

# %% [markdown]
# Выделю 2 новых датафрейма из исходного, удалю дубликаты и сброшу индексы.
# Также удалю из исходного датафрейма столбцы 'education' и 'family_status', чтобы обращаться к значениям по идентификаторам через созданные словари.

# %%
data_education = data[['education', 'education_id']]
data_family = data[['family_status', 'family_status_id']]
data_education = data_education.drop_duplicates().reset_index(drop=True)
data_family = data_family.drop_duplicates().reset_index(drop=True)

data = data[['children', 'days_employed', 'dob_years', 'education_id', 'family_status_id', 'gender', 'income_type', 'debt', 'total_income', 'purpose', 'years_employed']]
display(data)
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 0             1    8437.673028         42             0                 0
# 1             1    4024.803754         36             1                 0
# 2             0    5623.422610         33             1                 0
# 3             3    4124.747207         32             1                 0
# 4             0   14177.753002         53             1                 1
# ...         ...            ...        ...           ...               ...
# 21449         1    4529.316663         43             1                 1
# 21450         0   14330.725172         67             1                 0
# 21451         1    2113.346888         38             1                 1
# 21452         3    3112.481705         38             1                 0
# 21453         2    1984.507589         40             1                 0
#
#       gender income_type  debt  total_income                     purpose  \
# 0          F   сотрудник     0        253875                       жилье
# 1          F   сотрудник     0        112080                  автомобиль
# 2          M   сотрудник     0        145885                       жилье
# 3          M   сотрудник     0        267628  дополнительное образование
# 4          F   пенсионер     0        158616                     свадьба
# ...      ...         ...   ...           ...                         ...
# 21449      F   компаньон     0        224791                       жилье
# 21450      F   пенсионер     0        155999                  автомобиль
# 21451      M   сотрудник     1         89672                недвижимость
# 21452      M   сотрудник     1        244093                  автомобиль
# 21453      F   сотрудник     0         82047                  автомобиль
#
#        years_employed
# 0                  23
# 1                  11
# 2                  15
# 3                  11
# 4                  38
# ...               ...
# 21449              12
# 21450              39
# 21451               5
# 21452               8
# 21453               5
#
# [21454 rows x 11 columns]

# %% [markdown]
# ##  Категоризация дохода

# %% [markdown]
# Проведу классификацию заемщиков по уровню дохода, для этого напишу функцию, и результат будет указан в новом столбце.

# %%
def total_income_category(income):
    if income <= 30000:
        return 'E'
    if 30001 <= income <= 50000:
        return 'D'
    if 50001 <= income <= 200000:
        return 'C'
    if 200001 <= income <= 1000000:
        return 'B'
    if income >= 1000001:
        return 'A'
data['total_income_category'] = data['total_income'].apply(total_income_category)
display(data)
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 0             1    8437.673028         42             0                 0
# 1             1    4024.803754         36             1                 0
# 2             0    5623.422610         33             1                 0
# 3             3    4124.747207         32             1                 0
# 4             0   14177.753002         53             1                 1
# ...         ...            ...        ...           ...               ...
# 21449         1    4529.316663         43             1                 1
# 21450         0   14330.725172         67             1                 0
# 21451         1    2113.346888         38             1                 1
# 21452         3    3112.481705         38             1                 0
# 21453         2    1984.507589         40             1                 0
#
#       gender income_type  debt  total_income                     purpose  \
# 0          F   сотрудник     0        253875                       жилье
# 1          F   сотрудник     0        112080                  автомобиль
# 2          M   сотрудник     0        145885                       жилье
# 3          M   сотрудник     0        267628  дополнительное образование
# 4          F   пенсионер     0        158616                     свадьба
# ...      ...         ...   ...           ...                         ...
# 21449      F   компаньон     0        224791                       жилье
# 21450      F   пенсионер     0        155999                  автомобиль
# 21451      M   сотрудник     1         89672                недвижимость
# 21452      M   сотрудник     1        244093                  автомобиль
# 21453      F   сотрудник     0         82047                  автомобиль
#
#        years_employed total_income_category
# 0                  23                     B
# 1                  11                     C
# 2                  15                     C
# 3                  11                     B
# 4                  38                     C
# ...               ...                   ...
# 21449              12                     B
# 21450              39                     C
# 21451               5                     C
# 21452               8                     B
# 21453               5                     C
#
# [21454 rows x 12 columns]

# %% [markdown]
# ## Категоризация целей кредита

# %% [markdown]
# Создам столбец 'purpose_category', в котором будет 4 вида категорий: 'операции с автомобилем','операции с недвижимостью','проведение свадьбы','получение образования'. Это нужно для дальнейшего выявления зависимости наличия задолженности от общей цели взятия кредита.

# %%
def purpose_type(purpose):
    if purpose in ['жилье', 'недвижимость', 'покупка коммерческой недвижимости', 'покупка жилья для сдачи', 'строительство собственной недвижимости', 'строительство жилой недвижимости', 'строительство недвижимости', 'ремонт жилья']:
        return 'операции с недвижимостью'
    if purpose in ['автомобиль', 'сделка с подержанным автомобилем']:
        return 'операции с автомобилем'
    if purpose == 'свадьба':
        return 'проведение свадьбы'
    if purpose in ['высшее образование', 'дополнительное образование', 'профильное образование', 'образование']:
        return 'получение образования'
data['purpose_category'] = data['purpose'].apply(purpose_type)
display(data)
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 0             1    8437.673028         42             0                 0
# 1             1    4024.803754         36             1                 0
# 2             0    5623.422610         33             1                 0
# 3             3    4124.747207         32             1                 0
# 4             0   14177.753002         53             1                 1
# ...         ...            ...        ...           ...               ...
# 21449         1    4529.316663         43             1                 1
# 21450         0   14330.725172         67             1                 0
# 21451         1    2113.346888         38             1                 1
# 21452         3    3112.481705         38             1                 0
# 21453         2    1984.507589         40             1                 0
#
#       gender income_type  debt  total_income                     purpose  \
# 0          F   сотрудник     0        253875                       жилье
# 1          F   сотрудник     0        112080                  автомобиль
# 2          M   сотрудник     0        145885                       жилье
# 3          M   сотрудник     0        267628  дополнительное образование
# 4          F   пенсионер     0        158616                     свадьба
# ...      ...         ...   ...           ...                         ...
# 21449      F   компаньон     0        224791                       жилье
# 21450      F   пенсионер     0        155999                  автомобиль
# 21451      M   сотрудник     1         89672                недвижимость
# 21452      M   сотрудник     1        244093                  автомобиль
# 21453      F   сотрудник     0         82047                  автомобиль
#
#        years_employed total_income_category          purpose_category
# 0                  23                     B  операции с недвижимостью
# 1                  11                     C    операции с автомобилем
# 2                  15                     C  операции с недвижимостью
# 3                  11                     B     получение образования
# 4                  38                     C        проведение свадьбы
# ...               ...                   ...                       ...
# 21449              12                     B  операции с недвижимостью
# 21450              39                     C    операции с автомобилем
# 21451               5                     C  операции с недвижимостью
# 21452               8                     B    операции с автомобилем
# 21453               5                     C    операции с автомобилем
#
# [21454 rows x 13 columns]

# %% [markdown]
# ## Портрет клиентов, имеющих задолженность

# %% [markdown]
# У нас есть информация в столбце 'debt', имеется ли задолженность по возврату кредитов (0 или 1)
# Я решил добавить в основной датафрейм таблицу с семейным статусом.

# %%
data_new = data.merge(data_family, on='family_status_id', how='left')

# %% [markdown]
# Составлю несколько сводных таблиц, для понимания того, как характеристики заемщиков влияют на наличие задолженности по кредиту. Посмотрим, сколько заемщиков в каждой категории: по количеству детей, по семейному статусу, по доходу и по цели кредита.
# Также выведем средний долг по каждой категории.

# %%
display(data_new.pivot_table(index='children', values='debt', aggfunc=['mean','count']))
display(data_new.pivot_table(index='family_status', values='debt', aggfunc=['mean','count']))
display(data_new.pivot_table(index='total_income_category', values='debt', aggfunc=['mean','count']))
display(data_new.pivot_table(index='purpose_category', values='debt', aggfunc=['mean','count']))
# Out:
#               mean  count
#               debt   debt
# children
# 0         0.075438  14091
# 1         0.091658   4855
# 2         0.094925   2128
# 3         0.081818    330
# 4         0.097561     41
# 5         0.000000      9
#                            mean  count
#                            debt   debt
# family_status
# в разводе              0.071130   1195
# вдовец / вдова         0.065693    959
# гражданский брак       0.093471   4151
# женат / замужем        0.075452  12339
# не женат / не замужем  0.097509   2810
#                            mean  count
#                            debt   debt
# total_income_category
# A                      0.080000     25
# B                      0.070621   5041
# C                      0.084915  16016
# D                      0.060000    350
# E                      0.090909     22
#                               mean  count
#                               debt   debt
# purpose_category
# операции с автомобилем    0.093590   4306
# операции с недвижимостью  0.072334  10811
# получение образования     0.092200   4013
# проведение свадьбы        0.080034   2324

# %% [markdown]
# Создам подробную сводную таблицу для получения информации о взаимозависимости возврата кредита и следующих показателей: количества детей, семейное положение, цель кредита и уровень дохода. Таблица подробная и в некоторых подкатегориях не содержится данных.

# %%
pd.options.display.max_rows = 100
display(data_new.pivot_table(index=['family_status', 'total_income_category', 'purpose_category'], columns='children', values='debt', aggfunc='mean'))
# Out:
# children                                                                     0  \
# family_status         total_income_category purpose_category
# в разводе             A                     операции с недвижимостью  0.000000
#                       B                     операции с автомобилем    0.020408
#                                             операции с недвижимостью  0.063063
#                                             получение образования     0.142857
#                       C                     операции с автомобилем    0.083916
#                                             операции с недвижимостью  0.070064
#                                             получение образования     0.071429
#                       D                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
# вдовец / вдова        B                     операции с автомобилем    0.071429
#                                             операции с недвижимостью  0.038961
#                                             получение образования     0.080000
#                       C                     операции с автомобилем    0.101796
#                                             операции с недвижимостью  0.049738
#                                             получение образования     0.067114
#                       D                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
# гражданский брак      A                     операции с недвижимостью  0.000000
#                                             получение образования     1.000000
#                                             проведение свадьбы        0.000000
#                       B                     операции с автомобилем    0.058824
#                                             операции с недвижимостью  0.054422
#                                             получение образования     0.074627
#                                             проведение свадьбы        0.062857
#                       C                     операции с автомобилем    0.110048
#                                             операции с недвижимостью  0.085540
#                                             получение образования     0.148718
#                                             проведение свадьбы        0.079792
#                       D                     операции с автомобилем    0.200000
#                                             операции с недвижимостью  0.100000
#                                             получение образования     0.000000
#                                             проведение свадьбы        0.043478
#                       E                     получение образования     0.000000
#                                             проведение свадьбы        0.000000
# женат / замужем       A                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                       B                     операции с автомобилем    0.077320
#                                             операции с недвижимостью  0.062124
#                                             получение образования     0.055249
#                       C                     операции с автомобилем    0.069862
#                                             операции с недвижимостью  0.067430
#                                             получение образования     0.082064
#                       D                     операции с автомобилем    0.100000
#                                             операции с недвижимостью  0.037037
#                                             получение образования     0.029412
#                       E                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.250000
#                                             получение образования     0.000000
# не женат / не замужем A                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                       B                     операции с автомобилем    0.117647
#                                             операции с недвижимостью  0.076677
#                                             получение образования     0.104348
#                       C                     операции с автомобилем    0.123737
#                                             операции с недвижимостью  0.074346
#                                             получение образования     0.112760
#                       D                     операции с автомобилем    0.333333
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.200000
#                       E                     операции с недвижимостью  0.000000
#
# children                                                                     1  \
# family_status         total_income_category purpose_category
# в разводе             A                     операции с недвижимостью  0.000000
#                       B                     операции с автомобилем    0.100000
#                                             операции с недвижимостью  0.075000
#                                             получение образования     0.000000
#                       C                     операции с автомобилем    0.081633
#                                             операции с недвижимостью  0.070922
#                                             получение образования     0.041667
#                       D                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
# вдовец / вдова        B                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.076923
#                                             получение образования     0.000000
#                       C                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.078947
#                                             получение образования     0.272727
#                       D                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
# гражданский брак      A                     операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                                             проведение свадьбы        0.000000
#                       B                     операции с автомобилем    0.133333
#                                             операции с недвижимостью  0.090909
#                                             получение образования     0.222222
#                                             проведение свадьбы        0.031496
#                       C                     операции с автомобилем    0.168831
#                                             операции с недвижимостью  0.135417
#                                             получение образования     0.189189
#                                             проведение свадьбы        0.115288
#                       D                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                                             проведение свадьбы        0.142857
#                       E                     получение образования     0.000000
#                                             проведение свадьбы             NaN
# женат / замужем       A                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.500000
#                                             получение образования          NaN
#                       B                     операции с автомобилем    0.071429
#                                             операции с недвижимостью  0.071259
#                                             получение образования     0.074627
#                       C                     операции с автомобилем    0.105477
#                                             операции с недвижимостью  0.071823
#                                             получение образования     0.103297
#                       D                     операции с автомобилем    0.230769
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                       E                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
# не женат / не замужем A                     операции с автомобилем    0.000000
#                                             операции с недвижимостью       NaN
#                       B                     операции с автомобилем    0.055556
#                                             операции с недвижимостью  0.121212
#                                             получение образования     0.095238
#                       C                     операции с автомобилем    0.162162
#                                             операции с недвижимостью  0.109375
#                                             получение образования     0.098765
#                       D                     операции с автомобилем    0.000000
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       E                     операции с недвижимостью       NaN
#
# children                                                                     2  \
# family_status         total_income_category purpose_category
# в разводе             A                     операции с недвижимостью       NaN
#                       B                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.250000
#                       C                     операции с автомобилем    0.100000
#                                             операции с недвижимостью  0.081081
#                                             получение образования     0.066667
#                       D                     операции с автомобилем    1.000000
#                                             операции с недвижимостью  1.000000
#                                             получение образования          NaN
# вдовец / вдова        B                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.333333
#                                             получение образования          NaN
#                       C                     операции с автомобилем    0.200000
#                                             операции с недвижимостью  0.076923
#                                             получение образования     0.000000
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
# гражданский брак      A                     операции с недвижимостью       NaN
#                                             получение образования          NaN
#                                             проведение свадьбы             NaN
#                       B                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.235294
#                                             получение образования     0.000000
#                                             проведение свадьбы        0.035088
#                       C                     операции с автомобилем    0.133333
#                                             операции с недвижимостью  0.088889
#                                             получение образования     0.230769
#                                             проведение свадьбы        0.079755
#                       D                     операции с автомобилем    0.000000
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                                             проведение свадьбы        0.000000
#                       E                     получение образования          NaN
#                                             проведение свадьбы        0.000000
# женат / замужем       A                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                       B                     операции с автомобилем    0.119565
#                                             операции с недвижимостью  0.056277
#                                             получение образования     0.131579
#                       C                     операции с автомобилем    0.108333
#                                             операции с недвижимостью  0.089231
#                                             получение образования     0.106870
#                       D                     операции с автомобилем    0.200000
#                                             операции с недвижимостью  0.083333
#                                             получение образования     0.000000
#                       E                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
# не женат / не замужем A                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                       B                     операции с автомобилем    0.250000
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                       C                     операции с автомобилем    0.235294
#                                             операции с недвижимостью  0.100000
#                                             получение образования     0.076923
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       E                     операции с недвижимостью       NaN
#
# children                                                                     3  \
# family_status         total_income_category purpose_category
# в разводе             A                     операции с недвижимостью       NaN
#                       B                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
#                       C                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.111111
#                                             получение образования          NaN
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
# вдовец / вдова        B                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                       C                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
# гражданский брак      A                     операции с недвижимостью       NaN
#                                             получение образования          NaN
#                                             проведение свадьбы             NaN
#                       B                     операции с автомобилем    1.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.000000
#                                             проведение свадьбы        0.000000
#                       C                     операции с автомобилем    0.250000
#                                             операции с недвижимостью  0.000000
#                                             получение образования     0.250000
#                                             проведение свадьбы        0.190476
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования     0.000000
#                                             проведение свадьбы        1.000000
#                       E                     получение образования          NaN
#                                             проведение свадьбы             NaN
# женат / замужем       A                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
#                       B                     операции с автомобилем    0.062500
#                                             операции с недвижимостью  0.058824
#                                             получение образования     0.000000
#                       C                     операции с автомобилем    0.060606
#                                             операции с недвижимостью  0.086538
#                                             получение образования     0.075000
#                       D                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
#                       E                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
# не женат / не замужем A                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                       B                     операции с автомобилем    0.000000
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       C                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.500000
#                                             получение образования     0.000000
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       E                     операции с недвижимостью       NaN
#
# children                                                                     4  \
# family_status         total_income_category purpose_category
# в разводе             A                     операции с недвижимостью       NaN
#                       B                     операции с автомобилем    0.000000
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       C                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
# вдовец / вдова        B                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       C                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
# гражданский брак      A                     операции с недвижимостью       NaN
#                                             получение образования          NaN
#                                             проведение свадьбы             NaN
#                       B                     операции с автомобилем         NaN
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
#                                             проведение свадьбы        0.000000
#                       C                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
#                                             проведение свадьбы        0.000000
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                                             проведение свадьбы             NaN
#                       E                     получение образования          NaN
#                                             проведение свадьбы             NaN
# женат / замужем       A                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       B                     операции с автомобилем    0.333333
#                                             операции с недвижимостью  0.000000
#                                             получение образования          NaN
#                       C                     операции с автомобилем    0.000000
#                                             операции с недвижимостью  0.142857
#                                             получение образования     0.000000
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       E                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
# не женат / не замужем A                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                       B                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       C                     операции с автомобилем         NaN
#                                             операции с недвижимостью  1.000000
#                                             получение образования     0.000000
#                       D                     операции с автомобилем         NaN
#                                             операции с недвижимостью       NaN
#                                             получение образования          NaN
#                       E                     операции с недвижимостью       NaN
#
# children                                                                5
# family_status         total_income_category purpose_category
# в разводе             A                     операции с недвижимостью  NaN
#                       B                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                       C                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                       D                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
# вдовец / вдова        B                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                       C                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                       D                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
# гражданский брак      A                     операции с недвижимостью  NaN
#                                             получение образования     NaN
#                                             проведение свадьбы        NaN
#                       B                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                                             проведение свадьбы        NaN
#                       C                     операции с автомобилем    0.0
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                                             проведение свадьбы        0.0
#                       D                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                                             проведение свадьбы        NaN
#                       E                     получение образования     NaN
#                                             проведение свадьбы        NaN
# женат / замужем       A                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                       B                     операции с автомобилем    NaN
#                                             операции с недвижимостью  0.0
#                                             получение образования     0.0
#                       C                     операции с автомобилем    0.0
#                                             операции с недвижимостью  0.0
#                                             получение образования     NaN
#                       D                     операции с автомобилем    NaN
#                                             операции с недвижимостью  0.0
#                                             получение образования     NaN
#                       E                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
# не женат / не замужем A                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                       B                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                       C                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                       D                     операции с автомобилем    NaN
#                                             операции с недвижимостью  NaN
#                                             получение образования     NaN
#                       E                     операции с недвижимостью  NaN

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Я провел предобработку данных, выявил аномалии, дубликаты, пропущенные значения, и вернул датафрейм в корректном виде.
# Что касается вопросов исследования, на основе данных можно сделать выводы:
# - Заемщики без детей в среднем чаще имеют задолженности по кредиту
# - Заемщики категории 'вдовец / вдова' чаще других семейных категорий имеют задолженности по кредиту
# - Заемщики, относящиеся к группе 'не женат / не замужем', реже имеют задолженности по кредиту
# - Нет четкой зависимости между уровнем дохода и возвратом кредита в срок
# - Заемщики, целью кредита которых являются операции с автомобилем и получение образования гораздо реже
# имеют задолженности по кредиту, чем те, чья цель проведение свадьбы или операции с недвижимостью.
